# %%
import json
data='''
        {
        "name":"vikas",
        "phone":
            {
                "type":"intl",
                "number":"7709442919"
            }
        }
        '''
info=json.loads(data)
print("Name: ", info["name"])
# Out:
# Name:  vikas

# %%
import json
data='''
        [
            {"name":"vikas",
             "id":"2001",
             "x":"2"
            },
            {"name":"Sohan",
             "id":"2002",
             "x":"3"
            }
        
        ]
    '''
info=json.loads(data)
for item in info:
    print(item["name"])
# Out:
# vikas
# Sohan

# %%
import urllib.request, urllib.parse, urllib.error
import json
'''http://py4e-data.dr-chuck.net/comments_649023.json'''
url=input("URL: ")
data=urllib.request.urlopen(url).read()
info=json.loads(data)
#print(info)
lst=list()
for item in info["comments"]:
    #for cnt in item["comments"]:
        lst.append(int(item["count"]))
#print(lst)
tot=0
for num in lst:
    tot+=num
print(tot)
# Out:
# URL: http://py4e-data.dr-chuck.net/comments_649023.json
# 2473

# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl
'''Faculdade de Tecnologia do Estado de Sao Paulo'''
api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue

    print(json.dumps(js, indent=4))

    lat = js['results'][0]['geometry']['location']['lat']
    lng = js['results'][0]['geometry']['location']['lng']
    print('lat', lat, 'lng', lng)
    location = js['results'][0]['formatted_address']
    print(location)
# Out:
# Enter location: Faculdade de Tecnologia do Estado de Sao Paulo
# Retrieving http://py4e-data.dr-chuck.net/json?address=Faculdade+de+Tecnologia+do+Estado+de+Sao+Paulo&key=42
# Retrieved 2231 characters
# {
#     "results": [
#         {
#             "access_points": [],
#             "address_components": [
#                 {
#                     "long_name": "615",
#                     "short_name": "615",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Avenida Tiradentes",
#                     "short_name": "Av. Tiradentes",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Bom Retiro",
#                     "short_name": "Bom Retiro",
#                     "types": [
#                         "political",
#                         "sublocality",
#                         "sublocality_level_1"
#                     ]
#                 },
#                 {
#                     "long_name": "S\u00e3o Paulo",
#                     "short_name": "S\u00e3o Paulo",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "S\u00e3o Paulo",
#                     "short_name": "SP",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Brazil",
#                     "short_name": "BR",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "01124-060",
#                     "short_name": "01124-060",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "Av. Tiradentes, 615 - Bom Retiro, S\u00e3o Paulo - SP, 01124-060, Brazil",
#             "geometry": {
#                 "location": {
#                     "lat": -23.5295777,
#                     "lng": -46.6325629
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": -23.52822871970849,
#                         "lng": -46.6312139197085
#                     },
#                     "southwest": {
#                         "lat": -23.5309266802915,
#                         "lng": -46.63391188029149
#                     }
#                 }
#             },
#             "place_id": "ChIJdeuBi19YzpQRhNYX7o0VQrc",
#             "plus_code": {
#                 "compound_code": "F9C8+5X Bom Retiro, S\u00e3o Paulo - State of S\u00e3o Paulo, Brazil",
#                 "global_code": "588MF9C8+5X"
#             },
#             "types": [
#                 "establishment",
#                 "point_of_interest",
#                 "university"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# lat -23.5295777 lng -46.6325629
# Av. Tiradentes, 615 - Bom Retiro, São Paulo - SP, 01124-060, Brazil
